# %% [markdown]
# # Door Opening - RL Training (SAC)

# %%
from train_door import train, evaluate

train(timesteps=200000)
# Out:
# [robosuite WARNING] No private macro file found! (macros.py:57)
# [robosuite WARNING] It is recommended to use a private macro file (macros.py:58)
# [robosuite WARNING] To setup, run: python /opt/anaconda3/lib/python3.12/site-packages/robosuite/scripts/setup_macros.py (macros.py:59)
# [robosuite WARNING] Could not import robosuite_models. Some robots may not be available. If you want to use these robots, please install robosuite_models from source (https://github.com/ARISE-Initiative/robosuite_models) or through pip install. (__init__.py:30)
# [robosuite WARNING] Could not load the mink-based whole-body IK. Make sure you install related import properly, otherwise you will not be able to use the default IK controller setting for GR1 robot. (__init__.py:40)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /opt/anaconda3/lib/python3.12/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/anaconda3/lib/python3.12/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Starting training from scratch...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Training SAC on Door for 200000 timesteps...
# Logging to logs/door_sac_tb/SAC_3
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.06     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 245      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.97     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 274      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.54     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 286      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.1      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 292      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 8000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=10000, episode_reward=1.02 +/- 0.09
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 1.02     |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.13     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 197      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 10000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.96     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 165      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -7.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 3.34     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 146      |
# |    time_elapsed    | 95       |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -44.9    |
# |    critic_loss     | 0.447    |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 3.11     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 134      |
# |    time_elapsed    | 118      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 0.597    |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 3        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 129      |
# |    time_elapsed    | 138      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -46.4    |
# |    critic_loss     | 0.781    |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -24.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=20000, episode_reward=2.16 +/- 1.03
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 2.16     |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 0.642    |
# |    ent_coef        | 0.0533   |
# |    ent_coef_loss   | -25.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.25     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 113      |
# |    time_elapsed    | 175      |
# |    total_timesteps | 20000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.15     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 110      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 0.512    |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | -25      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.13     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 107      |
# |    time_elapsed    | 223      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.06     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 105      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 0.649    |
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | -15.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.13     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 103      |
# |    time_elapsed    | 271      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 0.562    |
# |    ent_coef        | 0.0074   |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=30000, episode_reward=5.46 +/- 2.52
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 5.46     |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 0.248    |
# |    ent_coef        | 0.00508  |
# |    ent_coef_loss   | -0.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.41     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 96       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 30000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.93     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 96       |
# |    time_elapsed    | 333      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 0.451    |
# |    ent_coef        | 0.00395  |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.96     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 96       |
# |    time_elapsed    | 352      |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 0.333    |
# |    ent_coef        | 0.00329  |
# |    ent_coef_loss   | -1.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.77     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 96       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.105    |
# |    ent_coef        | 0.00287  |
# |    ent_coef_loss   | 2.44     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.76     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 96       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.00233  |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=40000, episode_reward=10.36 +/- 5.44
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 10.4     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 0.0533   |
# |    ent_coef        | 0.00216  |
# |    ent_coef_loss   | -3.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 6.06     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 92       |
# |    time_elapsed    | 431      |
# |    total_timesteps | 40000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 6.98     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 92       |
# |    time_elapsed    | 453      |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.157    |
# |    ent_coef        | 0.00193  |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 7.41     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 92       |
# |    time_elapsed    | 477      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.0344   |
# |    ent_coef        | 0.00179  |
# |    ent_coef_loss   | -0.461   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 7.16     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 92       |
# |    time_elapsed    | 495      |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.153    |
# |    ent_coef        | 0.00176  |
# |    ent_coef_loss   | 3.85     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 6.92     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 92       |
# |    time_elapsed    | 516      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.0355   |
# |    ent_coef        | 0.00169  |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=50000, episode_reward=9.81 +/- 5.63
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 9.81     |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.548    |
# |    ent_coef        | 0.00167  |
# |    ent_coef_loss   | -0.694   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 8.19     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 89       |
# |    time_elapsed    | 556      |
# |    total_timesteps | 50000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ...
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | 2.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 72.7     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 82       |
# |    time_elapsed    | 2247     |
# |    total_timesteps | 186000   |
# | train/             |          |
# |    actor_loss      | -39.7    |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.012    |
# |    ent_coef_loss   | -2.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 78.9     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 82       |
# |    time_elapsed    | 2269     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=190000, episode_reward=299.67 +/- 132.52
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 300      |
# | time/              |          |
# |    total_timesteps | 190000   |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | 0.897    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179999   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 83.8     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 82       |
# |    time_elapsed    | 2310     |
# |    total_timesteps | 190000   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 93       |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 82       |
# |    time_elapsed    | 2333     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -39.1    |
# |    critic_loss     | 0.964    |
# |    ent_coef        | 0.0112   |
# |    ent_coef_loss   | 2.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 181999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 82       |
# |    time_elapsed    | 2358     |
# |    total_timesteps | 194000   |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 0.742    |
# |    ent_coef        | 0.011    |
# |    ent_coef_loss   | -0.666   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 82       |
# |    time_elapsed    | 2384     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 0.934    |
# |    ent_coef        | 0.011    |
# |    ent_coef_loss   | 0.786    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 82       |
# |    time_elapsed    | 2409     |
# |    total_timesteps | 198000   |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 5.22     |
# |    ent_coef        | 0.0112   |
# |    ent_coef_loss   | -0.852   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=200000, episode_reward=379.12 +/- 114.31
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 379      |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.0107   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 189999   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 81       |
# |    time_elapsed    | 2455     |
# |    total_timesteps | 200000   |
# ---------------------------------
# Training complete. Model saved to models/door_sac/

# %%
from train_door import train, evaluate
evaluate(render_mode=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from train_door import train, evaluate
# ----> 2 evaluate(render_mode="")
#
# TypeError: evaluate() got an unexpected keyword argument 'render_mode'
