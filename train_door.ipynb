# %% [markdown]
# # Door Opening - RL Training (SAC)

# %%
from train_door import train, evaluate

train(timesteps=200000)
# Out:
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Starting training from scratch...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training SAC on Door for 200000 timesteps...
# Logging to logs/door_sac_tb/SAC_6
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.06     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 240      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.24     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 255      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 4000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.15     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 268      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 6000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.2      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 276      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 8000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=10000, episode_reward=0.89 +/- 0.05
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.895    |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.73     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 190      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 10000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.79     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 159      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -33.4    |
# |    critic_loss     | 3.57     |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -7.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.15     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 146      |
# |    time_elapsed    | 95       |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 0.436    |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.03     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 137      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 5.73     |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.12     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 132      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -46      |
# |    critic_loss     | 0.642    |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -24.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=20000, episode_reward=0.70 +/- 0.02
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.701    |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -44      |
# |    critic_loss     | 0.705    |
# |    ent_coef        | 0.0535   |
# |    ent_coef_loss   | -25.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.19     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 113      |
# |    time_elapsed    | 176      |
# |    total_timesteps | 20000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.11     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 112      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -41.2    |
# |    critic_loss     | 0.699    |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.99     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 110      |
# |    time_elapsed    | 217      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 0.524    |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.92     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 110      |
# |    time_elapsed    | 235      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 0.914    |
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.84     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 110      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.00749  |
# |    ent_coef_loss   | -9.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=30000, episode_reward=0.82 +/- 0.35
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.822    |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -30.5    |
# |    critic_loss     | 0.296    |
# |    ent_coef        | 0.00549  |
# |    ent_coef_loss   | -0.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.76     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 102      |
# |    time_elapsed    | 291      |
# |    total_timesteps | 30000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.02     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 102      |
# |    time_elapsed    | 311      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.277    |
# |    ent_coef        | 0.00445  |
# |    ent_coef_loss   | -0.475   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.39     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 102      |
# |    time_elapsed    | 330      |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | -25.9    |
# |    critic_loss     | 0.158    |
# |    ent_coef        | 0.00382  |
# |    ent_coef_loss   | -3.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.55     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 103      |
# |    time_elapsed    | 349      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 0.142    |
# |    ent_coef        | 0.00324  |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.64     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 103      |
# |    time_elapsed    | 368      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 0.123    |
# |    ent_coef        | 0.00283  |
# |    ent_coef_loss   | 0.0414   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=40000, episode_reward=0.96 +/- 0.58
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.96     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.6      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 98       |
# |    time_elapsed    | 405      |
# |    total_timesteps | 40000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.56     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 98       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 0.0615   |
# |    ent_coef        | 0.00226  |
# |    ent_coef_loss   | -4.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.56     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 98       |
# |    time_elapsed    | 446      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.00207  |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.72     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 98       |
# |    time_elapsed    | 464      |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0551   |
# |    ent_coef        | 0.00181  |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.79     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 98       |
# |    time_elapsed    | 488      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.173    |
# |    ent_coef        | 0.00158  |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=50000, episode_reward=0.68 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.681    |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.0281   |
# |    ent_coef        | 0.00141  |
# |    ent_coef_loss   | 2.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.81     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 94       |
# |    time_elapsed    | 526      |
# |    total_timesteps | 50000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.84     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 94       |
# |    time_elapsed    | 547      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.0667   |
# |    ent_coef        | 0.00135  |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ...
# |    critic_loss     | 57.2     |
# |    ent_coef        | 0.0259   |
# |    ent_coef_loss   | 2.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.53     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 80       |
# |    time_elapsed    | 2299     |
# |    total_timesteps | 186000   |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 60.6     |
# |    ent_coef        | 0.0264   |
# |    ent_coef_loss   | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 5.97     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 81       |
# |    time_elapsed    | 2320     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -89.2    |
# |    critic_loss     | 5.57     |
# |    ent_coef        | 0.0265   |
# |    ent_coef_loss   | 2.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=190000, episode_reward=33.98 +/- 15.76
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 34       |
# | time/              |          |
# |    total_timesteps | 190000   |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 6.6      |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 6.84     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 80       |
# |    time_elapsed    | 2358     |
# |    total_timesteps | 190000   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 8.38     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 80       |
# |    time_elapsed    | 2379     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 67.7     |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -2.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 181999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 80       |
# |    time_elapsed    | 2400     |
# |    total_timesteps | 194000   |
# | train/             |          |
# |    actor_loss      | -84.5    |
# |    critic_loss     | 5.24     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | 0.397    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 18.9     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 80       |
# |    time_elapsed    | 2423     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -85.4    |
# |    critic_loss     | 5.46     |
# |    ent_coef        | 0.0274   |
# |    ent_coef_loss   | -0.671   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 80       |
# |    time_elapsed    | 2448     |
# |    total_timesteps | 198000   |
# | train/             |          |
# |    actor_loss      | -86.5    |
# |    critic_loss     | 6.59     |
# |    ent_coef        | 0.0248   |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=200000, episode_reward=134.51 +/- 87.48
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 135      |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -86.4    |
# |    critic_loss     | 57.9     |
# |    ent_coef        | 0.0241   |
# |    ent_coef_loss   | 0.283    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 189999   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 29.5     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 80       |
# |    time_elapsed    | 2487     |
# |    total_timesteps | 200000   |
# ---------------------------------
# Training complete. Model saved to models/door_sac/

# %%
from train_door import train, evaluate
evaluate(render_mode=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from train_door import train, evaluate
# ----> 2 evaluate(render_mode="")
#
# TypeError: evaluate() got an unexpected keyword argument 'render_mode'
