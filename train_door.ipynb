# %% [markdown]
# # Door Opening - RL Training (SAC)

# %%
from train_door import train, evaluate

train(timesteps=200000)
# Out:
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /opt/anaconda3/lib/python3.12/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/anaconda3/lib/python3.12/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Starting training from scratch...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training SAC on Door for 200000 timesteps...
# Logging to logs/door_sac_tb/SAC_4
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 0.872    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 315      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.01     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 321      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 0.95     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 318      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 6000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 0.995    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 318      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 8000     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=10000, episode_reward=0.92 +/- 0.05
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.917    |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.06     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 210      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 10000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.01     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 172      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -7.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.03     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 155      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 0.414    |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 0.997    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 146      |
# |    time_elapsed    | 108      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -47.6    |
# |    critic_loss     | 0.672    |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -19.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.13     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 140      |
# |    time_elapsed    | 128      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -46.9    |
# |    critic_loss     | 0.881    |
# |    ent_coef        | 0.094    |
# |    ent_coef_loss   | -23.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7999     |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=20000, episode_reward=3.54 +/- 3.65
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 3.54     |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -43.5    |
# |    critic_loss     | 6.6      |
# |    ent_coef        | 0.0537   |
# |    ent_coef_loss   | -25.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.45     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 119      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 20000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.67     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 115      |
# |    time_elapsed    | 190      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -41.6    |
# |    critic_loss     | 0.606    |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -25.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.6      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 110      |
# |    time_elapsed    | 216      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 0.398    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -21.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.59     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 108      |
# |    time_elapsed    | 240      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.011    |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.52     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 106      |
# |    time_elapsed    | 264      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 0.187    |
# |    ent_coef        | 0.00677  |
# |    ent_coef_loss   | -13      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=30000, episode_reward=0.86 +/- 0.34
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.86     |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 0.191    |
# |    ent_coef        | 0.00449  |
# |    ent_coef_loss   | -2.77    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.46     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 97       |
# |    time_elapsed    | 306      |
# |    total_timesteps | 30000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.42     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 96       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 0.143    |
# |    ent_coef        | 0.00321  |
# |    ent_coef_loss   | -3.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.43     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 96       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.00251  |
# |    ent_coef_loss   | -4.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.54     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 96       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 0.0977   |
# |    ent_coef        | 0.00202  |
# |    ent_coef_loss   | 2.47     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.59     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 96       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.00182  |
# |    ent_coef_loss   | -5.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=40000, episode_reward=0.95 +/- 0.75
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.955    |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.0791   |
# |    ent_coef        | 0.00152  |
# |    ent_coef_loss   | -5.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.6      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 92       |
# |    time_elapsed    | 430      |
# |    total_timesteps | 40000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.59     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 93       |
# |    time_elapsed    | 451      |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 0.125    |
# |    ent_coef        | 0.00124  |
# |    ent_coef_loss   | 3.59     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.55     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 93       |
# |    time_elapsed    | 471      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.729    |
# |    ent_coef        | 0.0011   |
# |    ent_coef_loss   | 2.64     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.52     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 93       |
# |    time_elapsed    | 493      |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.529    |
# |    ent_coef        | 0.000941 |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.49     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 93       |
# |    time_elapsed    | 513      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.564    |
# |    ent_coef        | 0.000842 |
# |    ent_coef_loss   | -4.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37999    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=50000, episode_reward=0.68 +/- 0.01
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 0.682    |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0173   |
# |    ent_coef        | 0.000741 |
# |    ent_coef_loss   | 3.57     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.46     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 90       |
# |    time_elapsed    | 551      |
# |    total_timesteps | 50000    |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 1.46     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 90       |
# |    time_elapsed    | 572      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.0161   |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -5.79    |
# ...
# |    actor_loss      | -45.4    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.014    |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 77       |
# |    time_elapsed    | 2413     |
# |    total_timesteps | 186000   |
# | train/             |          |
# |    actor_loss      | -48.3    |
# |    critic_loss     | 0.862    |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | -0.011   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 291      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 77       |
# |    time_elapsed    | 2432     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | 1.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=190000, episode_reward=208.03 +/- 174.91
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 208      |
# | time/              |          |
# |    total_timesteps | 190000   |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0136   |
# |    ent_coef_loss   | 1.88     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 76       |
# |    time_elapsed    | 2473     |
# |    total_timesteps | 190000   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 76       |
# |    time_elapsed    | 2500     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | 0.503    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 181999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 76       |
# |    time_elapsed    | 2526     |
# |    total_timesteps | 194000   |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 0.9      |
# |    ent_coef        | 0.0134   |
# |    ent_coef_loss   | -0.886   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 76       |
# |    time_elapsed    | 2552     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.0136   |
# |    ent_coef_loss   | -0.709   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 185999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 76       |
# |    time_elapsed    | 2579     |
# |    total_timesteps | 198000   |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.0132   |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187999   |
# ---------------------------------
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /opt/anaconda3/lib/python3.12/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Eval num_timesteps=200000, episode_reward=130.17 +/- 78.61
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | 130      |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 0.718    |
# |    ent_coef        | 0.013    |
# |    ent_coef_loss   | 0.676    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 189999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 76       |
# |    time_elapsed    | 2618     |
# |    total_timesteps | 200000   |
# ---------------------------------
# Training complete. Model saved to models/door_sac/

# %%
from train_door import train, evaluate
evaluate(render_mode=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from train_door import train, evaluate
# ----> 2 evaluate(render_mode="")
#
# TypeError: evaluate() got an unexpected keyword argument 'render_mode'
